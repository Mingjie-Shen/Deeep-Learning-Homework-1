# %% [markdown]
# <a href="https://colab.research.google.com/github/Mingjie-Shen/Deeep-Learning-Homework-and-Practice/blob/main/HW2_CIFAR10_ConvNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time
import torch
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %% [markdown]
# Data Augmentation Step
#
# Transforming the 3*32*32 array to a PIL image format -> Perform Data Transformations
# 1. Randomly crops 0.5 to 1 percentage of out of the input 3*32*32 image and resizes to 3*24*24 image
# 2. Randomly flip the image horizontally with a probability of 0.5
# 3. Randomly brighten the image with a factor selected uniformly from [max(0, 1 - brightness), 1 + brightness].
# 4. Randomly contrast the image with a factor selected uniformly from [max(0, 1 - contrast), 1 + contrast].
# -> Transform PIL image back to Tensor format

# %%
#Defining the data augmentation transformations
transformations = transforms.Compose([transforms.RandomHorizontalFlip(p=0.5),
                                      transforms.RandomVerticalFlip(p=0.5),
                                      #transforms.ColorJitter(brightness=0.3, contrast=0, saturation=0, hue=0),                              
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train = torchvision.datasets.CIFAR10(root='./CIFARdata', train=True,
                                        download=True, transform=transformations) #data augmentation transformations
data_train = torch.utils.data.DataLoader(train, batch_size=100, #Batch size = 100
                                          shuffle=True, num_workers=0)
#Transforming data and normalizing for the test set
transform_testset = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

test = torchvision.datasets.CIFAR10(root='./CIFARdata', train=False,
                                       download=True, transform=transform_testset)
data_test = torch.utils.data.DataLoader(test, batch_size=100,
                                         shuffle=False, num_workers=0)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./CIFARdata/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./CIFARdata/cifar-10-python.tar.gz to ./CIFARdata
# Files already downloaded and verified

# %%
##########

# Define deep convolution network model here
class CIFAR10Model(nn.Module):
  def __init__(self,num_outputs):
    super(CIFAR10Model,self).__init__()

    #the input size=(3,32,32)
    self.conv1=nn.Sequential(nn.Conv2d(3,64,kernel_size=4,padding=2),#output=(64,33,33)
                             nn.ReLU(),
                             nn.BatchNorm2d(64))
    
    #the input size=(64,33,33)
    self.conv2=nn.Sequential(nn.Conv2d(64,64,kernel_size=4,padding=2),#output=(64,34,34)
                             nn.ReLU(),
                             nn.MaxPool2d(kernel_size=2,stride=2),#output=(64,17,17)
                             nn.Dropout2d(0.2))
    
    #the input size=(64,17,17)
    self.conv3=nn.Sequential(nn.Conv2d(64,64,kernel_size=4,padding=2),#output=(64,18,18)
                             nn.ReLU(),
                             nn.BatchNorm2d(64))
    
    #the input size=(64,18,18)
    self.conv4=nn.Sequential(nn.Conv2d(64,64,kernel_size=4,padding=2),#output=(64,19,19)
                             nn.ReLU(),
                             nn.MaxPool2d(kernel_size=2,stride=2),#output=(64,9,9)
                             nn.Dropout2d(0.2))
    
    #the input size=(64,9,9)
    self.conv5=nn.Sequential(nn.Conv2d(64,64,kernel_size=4,padding=2),#output=(64,10,10)
                             nn.ReLU(),
                             nn.BatchNorm2d(64))
    
    #the input size=(64,10,10)
    self.conv6=nn.Sequential(nn.Conv2d(64,64,kernel_size=3),#output=(64,8,8)
                             nn.ReLU(),
                             nn.Dropout2d(0.2))
    
    #the input size=(64,8,8)
    self.conv7=nn.Sequential(nn.Conv2d(64,64,kernel_size=3),#output=(64,6,6)
                             nn.ReLU(),
                             nn.BatchNorm2d(64))
    
    #the input size=(64,6,6)
    self.conv8=nn.Sequential(nn.Conv2d(64,64,kernel_size=3),#output=(64,4,4)
                             nn.ReLU(),
                             nn.BatchNorm2d(64),
                             nn.Dropout2d(0.2))
    
    #the input size=(64,4,4)
    self.fc1=nn.Linear(64*4*4,500)
    self.fc2=nn.Linear(500,500)
    self.fc3=nn.Linear(500,num_outputs)

  def forward(self,x):
    x=self.conv1(x)
    x=self.conv2(x)
    x=self.conv3(x)
    x=self.conv4(x)
    x=self.conv5(x)
    x=self.conv6(x)
    x=self.conv7(x)
    x=self.conv8(x)
    x=self.fc1(x.reshape(-1,64*4*4))
    x=self.fc2(x)
    x=self.fc3(x)
    return F.log_softmax(x,dim=1)

# %%
#Parameters
num_outputs = 10 #10 classes
heuristic = True #Choosing from heuristic and Monte Carlo approximation

model = CIFAR10Model(num_outputs)
#model.load_state_dict(torch.load('params_cifar10_dcnn_LR001.ckpt')) #To load a saved model 
print ('\nModel Architecture is:\n', model)
model.cuda() #Sending the model to the GPU
batch_size = 100  #Batch size
loss_func = nn.CrossEntropyLoss() #Cross entropy loss function
if heuristic:
    model.train()
LR = 0.001 #Learning rate 
train_accuracy = []
'''
Train Mode
Create the batch -> Zero the gradients -> Forward Propagation -> Calculating the loss 
-> Backpropagation -> Optimizer updating the parameters -> Prediction 
'''
start_time = time.time()
for epoch in range(250):  # loop over the dataset multiple times
    #Defining the learning rate based on the no. of epochs
    if (epoch > 50):
        LR = 0.001
    if (epoch > 100):
        LR = 0.0001
    if (epoch > 200):
        LR = 0.00001
    optimizer = optim.Adam(model.parameters(), lr=LR) #ADAM optimizer
    running_loss = 0.0
    for i, batch in enumerate(data_train, 0):
        data, target = batch
        data, target = Variable(data).cuda(), Variable(target).cuda()
        optimizer.zero_grad() #Zero the gradients at each epoch
        output = model(data)#Forward propagation
        #Negative Log Likelihood Objective function
        loss = loss_func(output, target)
        loss.backward() #Backpropagation 
        optimizer.step() #Updating the parameters using ADAM optimizer
        prediction = output.data.max(1)[1] #Label Prediction 
        accuracy = (float(prediction.eq(target.data).sum())/float(batch_size))*100.0 #Computing the training accuracy
        train_accuracy.append(accuracy)   
    accuracy_epoch = np.mean(train_accuracy)
    print('\nIn epoch ', epoch,' the accuracy of the training set =', accuracy_epoch)
end_time = time.time()
# Out:
# Model Architecture is:
#  CIFAR10Model(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout2d(p=0.2, inplace=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout2d(p=0.2, inplace=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): Dropout2d(p=0.2, inplace=False)
#   )
#   (conv7): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv8): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout2d(p=0.2, inplace=False)
#   )
#   (fc1): Linear(in_features=1024, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=500, bias=True)
#   (fc3): Linear(in_features=500, out_features=10, bias=True)
# )
#
# In epoch  0  the accuracy of the training set = 34.72
#
# In epoch  1  the accuracy of the training set = 40.497
#
# In epoch  2  the accuracy of the training set = 45.20933333333333
#
# In epoch  3  the accuracy of the training set = 48.7875
#
# In epoch  4  the accuracy of the training set = 51.6148
#
# In epoch  5  the accuracy of the training set = 53.847
#
# In epoch  6  the accuracy of the training set = 55.690285714285714
#
# In epoch  7  the accuracy of the training set = 57.2965
#
# In epoch  8  the accuracy of the training set = 58.69733333333333
#
# In epoch  9  the accuracy of the training set = 59.893
#
# In epoch  10  the accuracy of the training set = 60.95727272727273
#
# In epoch  11  the accuracy of the training set = 61.91766666666667
#
# In epoch  12  the accuracy of the training set = 62.822
#
# In epoch  13  the accuracy of the training set = 63.61542857142857
#
# In epoch  14  the accuracy of the training set = 64.36573333333334
#
# In epoch  15  the accuracy of the training set = 65.05275
#
# In epoch  16  the accuracy of the training set = 65.69729411764706
#
# In epoch  17  the accuracy of the training set = 66.29155555555556
#
# In epoch  18  the accuracy of the training set = 66.8401052631579
#
# In epoch  19  the accuracy of the training set = 67.3389
#
# In epoch  20  the accuracy of the training set = 67.81590476190476
#
# In epoch  21  the accuracy of the training set = 68.27872727272727
#
# In epoch  22  the accuracy of the training set = 68.70478260869565
#
# In epoch  23  the accuracy of the training set = 69.11475
#
# In epoch  24  the accuracy of the training set = 69.49928
#
# In epoch  25  the accuracy of the training set = 69.86638461538462
#
# In epoch  26  the accuracy of the training set = 70.22111111111111
#
# In epoch  27  the accuracy of the training set = 70.55742857142857
#
# In epoch  28  the accuracy of the training set = 70.87468965517242
#
# In epoch  29  the accuracy of the training set = 71.18186666666666
#
# In epoch  30  the accuracy of the training set = 71.47406451612903
#
# In epoch  31  the accuracy of the training set = 71.758125
#
# In epoch  32  the accuracy of the training set = 72.02763636363636
#
# In epoch  33  the accuracy of the training set = 72.29794117647059
#
# In epoch  34  the accuracy of the training set = 72.5504
#
# In epoch  35  the accuracy of the training set = 72.79322222222223
#
# In epoch  36  the accuracy of the training set = 73.02875675675676
#
# In epoch  37  the accuracy of the training set = 73.25257894736842
#
# In epoch  38  the accuracy of the training set = 73.46820512820513
#
# In epoch  39  the accuracy of the training set = 73.67525
#
# In epoch  40  the accuracy of the training set = 73.88278048780488
#
# In epoch  41  the accuracy of the training set = 74.08304761904762
#
# In epoch  42  the accuracy of the training set = 74.27339534883721
#
# In epoch  43  the accuracy of the training set = 74.45627272727273
#
# In epoch  44  the accuracy of the training set = 74.63275555555556
#
# In epoch  45  the accuracy of the training set = 74.80921739130434
#
# In epoch  46  the accuracy of the training set = 74.97910638297873
#
# In epoch  47  the accuracy of the training set = 75.14266666666667
#
# In epoch  48  the accuracy of the training set = 75.30514285714285
#
# In epoch  49  the accuracy of the training set = 75.46308
#
# In epoch  50  the accuracy of the training set = 75.61925490196079
#
# In epoch  51  the accuracy of the training set = 75.77019230769231
#
# In epoch  52  the accuracy of the training set = 75.91362264150943
#
# In epoch  53  the accuracy of the training set = 76.05611111111111
#
# In epoch  54  the accuracy of the training set = 76.1944
#
# In epoch  55  the accuracy of the training set = 76.33046428571429
#
# In epoch  56  the accuracy of the training set = 76.46487719298246
#
# In epoch  57  the accuracy of the training set = 76.59220689655173
#
# In epoch  58  the accuracy of the training set = 76.71881355932203
#
# In epoch  59  the accuracy of the training set = 76.84336666666667
#
# In epoch  60  the accuracy of the training set = 76.96813114754099
#
# In epoch  61  the accuracy of the training set = 77.08932258064516
#
# In epoch  62  the accuracy of the training set = 77.20380952380953
#
# In epoch  63  the accuracy of the training set = 77.31334375
#
# In epoch  64  the accuracy of the training set = 77.42486153846154
#
# In epoch  65  the accuracy of the training set = 77.53272727272727
#
# In epoch  66  the accuracy of the training set = 77.63973134328359
#
# In epoch  67  the accuracy of the training set = 77.7434705882353
#
# In epoch  68  the accuracy of the training set = 77.84750724637681
#
# In epoch  69  the accuracy of the training set = 77.95128571428572
#
# In epoch  70  the accuracy of the training set = 78.04892957746479
#
# In epoch  71  the accuracy of the training set = 78.14580555555555
#
# In epoch  72  the accuracy of the training set = 78.24202739726027
#
# In epoch  73  the accuracy of the training set = 78.33764864864865
#
# In epoch  74  the accuracy of the training set = 78.42818666666666
#
# In epoch  75  the accuracy of the training set = 78.51905263157894
#
# In epoch  76  the accuracy of the training set = 78.60735064935065
#
# In epoch  77  the accuracy of the training set = 78.69679487179488
#
# In epoch  78  the accuracy of the training set = 78.7846329113924
#
# In epoch  79  the accuracy of the training set = 78.868475
#
# In epoch  80  the accuracy of the training set = 78.95182716049382
#
# In epoch  81  the accuracy of the training set = 79.0330975609756
#
# In epoch  82  the accuracy of the training set = 79.1121686746988
#
# In epoch  83  the accuracy of the training set = 79.19204761904761
#
# In epoch  84  the accuracy of the training set = 79.27348235294117
#
# In epoch  85  the accuracy of the training set = 79.35227906976745
#
# In epoch  86  the accuracy of the training set = 79.42871264367817
#
# In epoch  87  the accuracy of the training set = 79.50352272727272
#
# In epoch  88  the accuracy of the training set = 79.57694382022471
#
# In epoch  89  the accuracy of the training set = 79.6498
#
# In epoch  90  the accuracy of the training set = 79.7221978021978
#
# In epoch  91  the accuracy of the training set = 79.7921304347826
#
# In epoch  92  the accuracy of the training set = 79.86133333333333
#
# In epoch  93  the accuracy of the training set = 79.9291914893617
#
# In epoch  94  the accuracy of the training set = 79.9984
#
# In epoch  95  the accuracy of the training set = 80.0634375
#
# In epoch  96  the accuracy of the training set = 80.12723711340206
#
# In epoch  97  the accuracy of the training set = 80.19261224489796
#
# In epoch  98  the accuracy of the training set = 80.25608080808081
#
# In epoch  99  the accuracy of the training set = 80.317
#
# In epoch  100  the accuracy of the training set = 80.37948514851485
#
# In epoch  101  the accuracy of the training set = 80.45056862745098
#
# In epoch  102  the accuracy of the training set = 80.52656310679612
#
# In epoch  103  the accuracy of the training set = 80.60203846153846
#
# In epoch  104  the accuracy of the training set = 80.67921904761904
#
# In epoch  105  the accuracy of the training set = 80.7541320754717
#
# In epoch  106  the accuracy of the training set = 80.83097196261683
#
# In epoch  107  the accuracy of the training set = 80.90605555555555
#
# In epoch  108  the accuracy of the training set = 80.97954128440367
#
# In epoch  109  the accuracy of the training set = 81.05103636363637
#
# In epoch  110  the accuracy of the training set = 81.12196396396396
#
# In epoch  111  the accuracy of the training set = 81.19228571428572
#
# In epoch  112  the accuracy of the training set = 81.26332743362832
#
# In epoch  113  the accuracy of the training set = 81.3328947368421
#
# In epoch  114  the accuracy of the training set = 81.40196521739131
#
# In epoch  115  the accuracy of the training set = 81.47048275862069
#
# In epoch  116  the accuracy of the training set = 81.53863247863248
#
# In epoch  117  the accuracy of the training set = 81.60464406779661
#
# In epoch  118  the accuracy of the training set = 81.67090756302521
#
# In epoch  119  the accuracy of the training set = 81.73643333333334
#
# In epoch  120  the accuracy of the training set = 81.80003305785124
#
# In epoch  121  the accuracy of the training set = 81.86252459016393
#
# In epoch  122  the accuracy of the training set = 81.92538211382114
#
# In epoch  123  the accuracy of the training set = 81.98667741935483
#
# In epoch  124  the accuracy of the training set = 82.04816
#
# In epoch  125  the accuracy of the training set = 82.10938095238095
#
# In epoch  126  the accuracy of the training set = 82.16795275590552
#
# In epoch  127  the accuracy of the training set = 82.227703125
#
# In epoch  128  the accuracy of the training set = 82.28634108527132
#
# In epoch  129  the accuracy of the training set = 82.34398461538461
#
# In epoch  130  the accuracy of the training set = 82.40059541984733
#
# In epoch  131  the accuracy of the training set = 82.45583333333333
#
# In epoch  132  the accuracy of the training set = 82.51141353383458
#
# In epoch  133  the accuracy of the training set = 82.56673134328358
#
# In epoch  134  the accuracy of the training set = 82.62053333333333
#
# In epoch  135  the accuracy of the training set = 82.67288235294117
#
# In epoch  136  the accuracy of the training set = 82.72516788321168
#
# In epoch  137  the accuracy of the training set = 82.77656521739131
#
# In epoch  138  the accuracy of the training set = 82.82756834532374
#
# In epoch  139  the accuracy of the training set = 82.8782
#
# In epoch  140  the accuracy of the training set = 82.92902127659575
#
# In epoch  141  the accuracy of the training set = 82.97876056338028
#
# In epoch  142  the accuracy of the training set = 83.02700699300699
#
# In epoch  143  the accuracy of the training set = 83.07597222222222
#
# In epoch  144  the accuracy of the training set = 83.12427586206897
#
# In epoch  145  the accuracy of the training set = 83.17342465753424
#
# In epoch  146  the accuracy of the training set = 83.21995918367347
#
# In epoch  147  the accuracy of the training set = 83.26687837837838
#
# In epoch  148  the accuracy of the training set = 83.3126845637584
#
# In epoch  149  the accuracy of the training set = 83.35893333333334
#
# In epoch  150  the accuracy of the training set = 83.40438410596026
#
# In epoch  151  the accuracy of the training set = 83.44596052631579
#
# In epoch  152  the accuracy of the training set = 83.48857516339869
#
# In epoch  153  the accuracy of the training set = 83.53146753246753
#
# In epoch  154  the accuracy of the training set = 83.57451612903226
#
# In epoch  155  the accuracy of the training set = 83.61658974358974
#
# In epoch  156  the accuracy of the training set = 83.65824203821656
#
# In epoch  157  the accuracy of the training set = 83.6996582278481
#
# In epoch  158  the accuracy of the training set = 83.74045283018867
#
# In epoch  159  the accuracy of the training set = 83.781125
#
# In epoch  160  the accuracy of the training set = 83.82221118012423
#
# In epoch  161  the accuracy of the training set = 83.86266666666667
#
# In epoch  162  the accuracy of the training set = 83.90137423312883
#
# In epoch  163  the accuracy of the training set = 83.94
#
# In epoch  164  the accuracy of the training set = 83.97768484848484
#
# In epoch  165  the accuracy of the training set = 84.01631325301204
#
# In epoch  166  the accuracy of the training set = 84.05479041916168
#
# In epoch  167  the accuracy of the training set = 84.09063095238095
#
# In epoch  168  the accuracy of the training set = 84.12769230769231
#
# In epoch  169  the accuracy of the training set = 84.16484705882353
#
# In epoch  170  the accuracy of the training set = 84.20205847953217
#
# In epoch  171  the accuracy of the training set = 84.23862790697675
#
# In epoch  172  the accuracy of the training set = 84.27493641618497
#
# In epoch  173  the accuracy of the training set = 84.31041379310345
#
# In epoch  174  the accuracy of the training set = 84.34437714285714
#
# In epoch  175  the accuracy of the training set = 84.37845454545455
#
# In epoch  176  the accuracy of the training set = 84.41227118644068
#
# In epoch  177  the accuracy of the training set = 84.44586516853933
#
# In epoch  178  the accuracy of the training set = 84.47831284916201
#
# In epoch  179  the accuracy of the training set = 84.51126666666667
#
# In epoch  180  the accuracy of the training set = 84.54418784530387
#
# In epoch  181  the accuracy of the training set = 84.57654945054945
#
# In epoch  182  the accuracy of the training set = 84.60881967213115
#
# In epoch  183  the accuracy of the training set = 84.64072826086957
#
# In epoch  184  the accuracy of the training set = 84.67267027027027
#
# In epoch  185  the accuracy of the training set = 84.70315053763441
#
# In epoch  186  the accuracy of the training set = 84.73442780748663
#
# In epoch  187  the accuracy of the training set = 84.7656170212766
#
# In epoch  188  the accuracy of the training set = 84.79676190476191
#
# In epoch  189  the accuracy of the training set = 84.82796842105263
#
# In epoch  190  the accuracy of the training set = 84.85849214659686
#
# In epoch  191  the accuracy of the training set = 84.88889583333334
#
# In epoch  192  the accuracy of the training set = 84.9181243523316
#
# In epoch  193  the accuracy of the training set = 84.94735051546392
#
# In epoch  194  the accuracy of the training set = 84.9766358974359
#
# In epoch  195  the accuracy of the training set = 85.00474489795918
#
# In epoch  196  the accuracy of the training set = 85.03298477157361
#
# In epoch  197  the accuracy of the training set = 85.06042424242425

# %%
#torch.save(model.state_dict(), 'params_cifar10_dcnn_LR001.ckpt') #To save the trained model 
'''
Calculate accuracy of trained model on the Test Set
Create the batch ->  Forward Propagation -> Prediction 
'''
correct = 0
total = 0
test_accuracy = []

# %%
if heuristic:
    MonteCarlo = 1 #Only one itertion if we are using the heuristic 
    #Comparing the accuarcy of the heuristic and Monte Carlo Method  
    model.eval()
    #Disable the droupout layer during test time
    #This scales the activation with probability of dropout p at test time 
    #So this is applying the heuristic at the test time
else:
    MonteCarlo = 100 #100 Monte Carlo iterations for comparision with heuristic method.
    
for batch in data_test:
    data, target = batch
    data, target  = Variable(data).cuda(), Variable(target).cuda()
    for k in range (MonteCarlo):
        if k ==0:
            output = model(data)  #Forward propagation     
        else:
            output+=model(data)  #Forward propagation     
    output/=MonteCarlo #Averaging the softmmax probabilities montecarlo no. of times 
    prediction = output.data.max(1)[1] #Label Prediction
    accuracy = (float(prediction.eq(target.data).sum())/float(batch_size))*100.0 #Computing the test accuracy
    test_accuracy.append(accuracy)
accuracy_test2 = np.mean(test_accuracy)
print('\nAccuracy on the test set = ', accuracy_test2)
